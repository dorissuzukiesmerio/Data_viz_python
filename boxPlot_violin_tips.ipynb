# %% [markdown]
# <a href="https://colab.research.google.com/github/dorissuzukiesmerio/Data_viz_python/blob/main/boxPlot_violin_tips.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load dataset 
tips = sns.load_dataset("tips")

# %%
sns.set(style="ticks", color_codes=True)

# %%
diamonds = sns.load_dataset("diamonds") # # style 
sns.catplot(x="color", y="price", kind="boxen",
            data=diamonds.sort_values("color"));

# %% [markdown]
# Violin Plot:

# %%
sns.catplot(x="day", y="tip", hue="sex",
            kind="violin", split=True, data=tips);
